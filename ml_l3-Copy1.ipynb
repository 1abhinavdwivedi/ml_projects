# %%
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/abhinav/Downloads'

# %%
df=pd.read_csv('wine.data',names=['class',"sepal_1","sepal_2","sepal_3","sepal_4","sepal_5","sepal_6","sepal_7","sepal_8","sepal_9","sepal_width","petal_length","petal_width","abc"])

# %%
df.head()
# Out:
#    class  sepal_1  sepal_2  sepal_3  sepal_4  sepal_5  sepal_6  sepal_7  \
# 0      1    14.23     1.71     2.43     15.6      127     2.80     3.06
# 1      1    13.20     1.78     2.14     11.2      100     2.65     2.76
# 2      1    13.16     2.36     2.67     18.6      101     2.80     3.24
# 3      1    14.37     1.95     2.50     16.8      113     3.85     3.49
# 4      1    13.24     2.59     2.87     21.0      118     2.80     2.69
#
#    sepal_8  sepal_9  sepal_width  petal_length  petal_width   abc
# 0     0.28     2.29         5.64          1.04         3.92  1065
# 1     0.26     1.28         4.38          1.05         3.40  1050
# 2     0.30     2.81         5.68          1.03         3.17  1185
# 3     0.24     2.18         7.80          0.86         3.45  1480
# 4     0.39     1.82         4.32          1.04         2.93   735

# %%
df.shape
# Out:
# (178, 14)

# %%
y= df.iloc[:,:1]

# %%
X= df.iloc[:,1:]

# %%
print(X.head())
print(y.head())
# Out:
#    sepal_1  sepal_2  sepal_3  sepal_4  sepal_5  sepal_6  sepal_7  sepal_8  \
# 0    14.23     1.71     2.43     15.6      127     2.80     3.06     0.28
# 1    13.20     1.78     2.14     11.2      100     2.65     2.76     0.26
# 2    13.16     2.36     2.67     18.6      101     2.80     3.24     0.30
# 3    14.37     1.95     2.50     16.8      113     3.85     3.49     0.24
# 4    13.24     2.59     2.87     21.0      118     2.80     2.69     0.39
#
#    sepal_9  sepal_width  petal_length  petal_width   abc
# 0     2.29         5.64          1.04         3.92  1065
# 1     1.28         4.38          1.05         3.40  1050
# 2     2.81         5.68          1.03         3.17  1185
# 3     2.18         7.80          0.86         3.45  1480
# 4     1.82         4.32          1.04         2.93   735
#    class
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
df.iloc[:7,:]
# Out:
#    class  sepal_1  sepal_2  sepal_3  sepal_4  sepal_5  sepal_6  sepal_7  \
# 0      1    14.23     1.71     2.43     15.6      127     2.80     3.06
# 1      1    13.20     1.78     2.14     11.2      100     2.65     2.76
# 2      1    13.16     2.36     2.67     18.6      101     2.80     3.24
# 3      1    14.37     1.95     2.50     16.8      113     3.85     3.49
# 4      1    13.24     2.59     2.87     21.0      118     2.80     2.69
# 5      1    14.20     1.76     2.45     15.2      112     3.27     3.39
# 6      1    14.39     1.87     2.45     14.6       96     2.50     2.52
#
#    sepal_8  sepal_9  sepal_width  petal_length  petal_width   abc
# 0     0.28     2.29         5.64          1.04         3.92  1065
# 1     0.26     1.28         4.38          1.05         3.40  1050
# 2     0.30     2.81         5.68          1.03         3.17  1185
# 3     0.24     2.18         7.80          0.86         3.45  1480
# 4     0.39     1.82         4.32          1.04         2.93   735
# 5     0.34     1.97         6.75          1.05         2.85  1450
# 6     0.30     1.98         5.25          1.02         3.58  1290

# %%
x=df.drop(['class'],axis=1)

# %%
#encode class values to numeric values

from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()
df['class']=label_encoder.fit_transform(df['class'])

# %%
df.head()
# Out:
#    class  sepal_1  sepal_2  sepal_3  sepal_4  sepal_5  sepal_6  sepal_7  \
# 0      0    14.23     1.71     2.43     15.6      127     2.80     3.06
# 1      0    13.20     1.78     2.14     11.2      100     2.65     2.76
# 2      0    13.16     2.36     2.67     18.6      101     2.80     3.24
# 3      0    14.37     1.95     2.50     16.8      113     3.85     3.49
# 4      0    13.24     2.59     2.87     21.0      118     2.80     2.69
#
#    sepal_8  sepal_9  sepal_width  petal_length  petal_width   abc
# 0     0.28     2.29         5.64          1.04         3.92  1065
# 1     0.26     1.28         4.38          1.05         3.40  1050
# 2     0.30     2.81         5.68          1.03         3.17  1185
# 3     0.24     2.18         7.80          0.86         3.45  1480
# 4     0.39     1.82         4.32          1.04         2.93   735

# %%
df.tail()
# Out:
#      class  sepal_1  sepal_2  sepal_3  sepal_4  sepal_5  sepal_6  sepal_7  \
# 173      2    13.71     5.65     2.45     20.5       95     1.68     0.61
# 174      2    13.40     3.91     2.48     23.0      102     1.80     0.75
# 175      2    13.27     4.28     2.26     20.0      120     1.59     0.69
# 176      2    13.17     2.59     2.37     20.0      120     1.65     0.68
# 177      2    14.13     4.10     2.74     24.5       96     2.05     0.76
#
#      sepal_8  sepal_9  sepal_width  petal_length  petal_width  abc
# 173     0.52     1.06          7.7          0.64         1.74  740
# 174     0.43     1.41          7.3          0.70         1.56  750
# 175     0.43     1.35         10.2          0.59         1.56  835
# 176     0.53     1.46          9.3          0.60         1.62  840
# 177     0.56     1.35          9.2          0.61         1.60  560

# %%
df.iloc[:7,:]
# Out:
#    sepal_length  sepal_1  sepal_2  sepal_3  sepal_4  sepal_5  sepal_6  \
# 0             1    14.23     1.71     2.43     15.6      127     2.80
# 1             1    13.20     1.78     2.14     11.2      100     2.65
# 2             1    13.16     2.36     2.67     18.6      101     2.80
# 3             1    14.37     1.95     2.50     16.8      113     3.85
# 4             1    13.24     2.59     2.87     21.0      118     2.80
# 5             1    14.20     1.76     2.45     15.2      112     3.27
# 6             1    14.39     1.87     2.45     14.6       96     2.50
#
#    sepal_7  sepal_8  sepal_9  sepal_width  petal_length  petal_width  class
# 0     3.06     0.28     2.29         5.64          1.04         3.92     94
# 1     2.76     0.26     1.28         4.38          1.05         3.40     92
# 2     3.24     0.30     2.81         5.68          1.03         3.17    101
# 3     3.49     0.24     2.18         7.80          0.86         3.45    116
# 4     2.69     0.39     1.82         4.32          1.04         2.93     66
# 5     3.39     0.34     1.97         6.75          1.05         2.85    115
# 6     2.52     0.30     1.98         5.25          1.02         3.58    110

# %%
x=df.drop(['class'],axis=1)

# %%
y=df['class']

# %%
print(x.head())
print(y.head())
# Out:
#                                            sepal_length  sepal_width  \
# 1 14.23 1.71 2.43 15.6 127 2.80 3.06 0.28          2.29         5.64
#   13.20 1.78 2.14 11.2 100 2.65 2.76 0.26          1.28         4.38
#   13.16 2.36 2.67 18.6 101 2.80 3.24 0.30          2.81         5.68
#   14.37 1.95 2.50 16.8 113 3.85 3.49 0.24          2.18         7.80
#   13.24 2.59 2.87 21.0 118 2.80 2.69 0.39          1.82         4.32
#
#                                            petal_length  petal_width
# 1 14.23 1.71 2.43 15.6 127 2.80 3.06 0.28          1.04         3.92
#   13.20 1.78 2.14 11.2 100 2.65 2.76 0.26          1.05         3.40
#   13.16 2.36 2.67 18.6 101 2.80 3.24 0.30          1.03         3.17
#   14.37 1.95 2.50 16.8 113 3.85 3.49 0.24          0.86         3.45
#   13.24 2.59 2.87 21.0 118 2.80 2.69 0.39          1.04         2.93
# 1    1065
# 1    1050
# 1    1185
# 1    1480
# 1     735
# Name: class, dtype: int64

# %%
print(x.tail())
print(y.tail())
# Out:
#      sepal_length  sepal_1  sepal_2  sepal_3  sepal_4  sepal_5  sepal_6  \
# 173             3    13.71     5.65     2.45     20.5       95     1.68
# 174             3    13.40     3.91     2.48     23.0      102     1.80
# 175             3    13.27     4.28     2.26     20.0      120     1.59
# 176             3    13.17     2.59     2.37     20.0      120     1.65
# 177             3    14.13     4.10     2.74     24.5       96     2.05
#
#      sepal_7  sepal_8  sepal_9  sepal_width  petal_length  petal_width
# 173     0.61     0.52     1.06          7.7          0.64         1.74
# 174     0.75     0.43     1.41          7.3          0.70         1.56
# 175     0.69     0.43     1.35         10.2          0.59         1.56
# 176     0.68     0.53     1.46          9.3          0.60         1.62
# 177     0.76     0.56     1.35          9.2          0.61         1.60
# 173    3
# 174    3
# 175    3
# 176    3
# 177    3
# Name: sepal_length, dtype: int64

# %%
#split dataset into train and test datasets
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=5)

# %%
#build random forest model

from sklearn.ensemble import RandomForestClassifier
rf_model=RandomForestClassifier(n_estimators=100)
rf_model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
#predict values of class

y_predict=rf_model.predict(x_test)

# %%
from sklearn import metrics
print("accuracy of the model is: ",metrics.accuracy_score(y_test,y_predict))
# Out:
# accuracy of the model is:  0.9444444444444444

# %%
rf_model.predict([[3,6,3,2,4,5,6,8,3,2,1,9,7],[3,4,2,2,5,6,7,2,1,6,7,2,1]])
# Out:
# /Users/abhinav/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([1, 1])

# %%
#confusion matrix
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
print(confusion_matrix(y_test,y_predict))

plot_confusion_matrix(rf_model,x_test,y_test)
plt.show()
# Out:
# [[21  2  0]
#  [ 0 17  1]
#  [ 0  0 13]]
# /Users/abhinav/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
#dtc_model = DecisionTreeClassifier(criterion='entropy',max_depth=3) 
dtc_model=DecisionTreeClassifier()

# %%
x_train.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 126           6.2          2.8           4.8          1.8
# 61            5.9          3.0           4.2          1.5
# 124           6.7          3.3           5.7          2.1
# 117           7.7          3.8           6.7          2.2
# 20            5.4          3.4           1.7          0.2

# %%
dtc=dtc_model.fit(x_train,y_train)

# %%
y_predict = dtc.predict(x_test)

# %%
from sklearn import metrics

# %%
print("accuracy of the decision tree model is: ",metrics.accuracy_score(y_test,y_predict))
# Out:
# accuracy of the decision tree model is:  0.9333333333333333
