# %%
import pandas as pd

# %%
s1= pd.Series([1,2,3,4,5])
print(s1)
type(s1)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# pandas.core.series.Series

# %%
s1=pd.Series([1,2,3,4,5], index=['a','b','c','d','e'])
print(s1)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
val1=[4,5,6,7]
s2=pd.Series(val1)
s3=pd.Series(val1,index=['d','e','f','g'])
print(s2)
print(s3)
# Out:
# 0    4
# 1    5
# 2    6
# 3    7
# dtype: int64
# d    4
# e    5
# f    6
# g    7
# dtype: int64

# %%
#creating series from dicitonary
d1={'a':1,'b':2,'c':3,'d':4,'e':5}
s2=pd.Series({'a':1,'b':2,'c':3,'d':4,'e':5})
s3=pd.Series(d1)
print(s2)
print(s3)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
#accessing elements or services
print(s2[:2])
print(s2[:2])
print(s2[1])
# Out:
# a    1
# b    2
# dtype: int64
# a    1
# b    2
# dtype: int64
# 2

# %%
#dataframe
df1=pd.DataFrame({'Name':['Anshu','Naman','Utkarsh'],'Marks':[70,75,78],'City':['Delhi','Ambala','Jaipur']})
print(df1)
# Out:
#       Name  Marks    City
# 0    Anshu     70   Delhi
# 1    Naman     75  Ambala
# 2  Utkarsh     78  Jaipur

# %%
df=pd.read_csv('/Users/abhinav/Downloads/train_1.csv')

# %%
print(df.head())
print(df.tail())
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
#describe
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
#df.loc[row,column]
df.loc[: ,('Occupation', 'Purchase')]
# Out:
#         Occupation  Purchase
# 0               10      8370
# 1               10     15200
# 2               10      1422
# 3               10      1057
# 4               16      7969
# ...            ...       ...
# 550063          13       368
# 550064           1       371
# 550065          15       137
# 550066           1       365
# 550067           0       490
#
# [550068 rows x 2 columns]

# %%
df.loc[5:12,('Occupation', 'Purchase')]
# Out:
#     Occupation  Purchase
# 5           15     15227
# 6            7     19215
# 7            7     15854
# 8            7     15686
# 9           20      7871
# 10          20      5254
# 11          20      3957
# 12          20      6073

# %%
#specifying row and columns ranges
df.iloc[5:10, 2:5]
# Out:
#   Gender    Age  Occupation
# 5      M  26-35          15
# 6      M  46-50           7
# 7      M  46-50           7
# 8      M  46-50           7
# 9      M  26-35          20

# %%
#specifying row range and column numbers
df.iloc[5:10, [2,4,5]]
# Out:
#   Gender  Occupation City_Category
# 5      M          15             A
# 6      M           7             B
# 7      M           7             B
# 8      M           7             B
# 9      M          20             A

# %%
print(df)
print(df[df.Purchase >12000])
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...
